# %% [markdown]
# <a href="https://colab.research.google.com/github/Nisarg0705/html-portfolio/blob/main/Credit_Card_Fraud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import tensorflow as tf

# %%
df_train= pd.read_csv('/content/fraudTrain.csv')
df_test= pd.read_csv('/content/fraudTest.csv')

# %%
df_train.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
# 2           2   2019-01-01 00:00:51    38859492057661
# 3           3   2019-01-01 00:01:16  3534093764340240
# 4           4   2019-01-01 00:03:06   375534208663984
#
#                              merchant       category     amt      first  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie
# 2                fraud_Lind-Buckridge  entertainment  220.11     Edward
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00     Jeremy
# 4                 fraud_Keeling-Crist       misc_pos   41.96      Tyler
#
#       last gender                        street  ...      lat      long  \
# 0    Banks      F                561 Perry Cove  ...  36.0788  -81.1781
# ...

# %%
df_test.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ...      lat      long  \
# 0   Elliott      M            351 Darlene Green  ...  33.9659  -80.9355
# ...

# %%
df_train.shape
# Out:
# (1296675, 23)

# %%
df_test.shape
# Out:
# (555719, 23)

# %%
df=pd.concat([df_train,df_test])

# %%
df.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
# 2           2   2019-01-01 00:00:51    38859492057661
# 3           3   2019-01-01 00:01:16  3534093764340240
# 4           4   2019-01-01 00:03:06   375534208663984
#
#                              merchant       category     amt      first  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie
# 2                fraud_Lind-Buckridge  entertainment  220.11     Edward
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00     Jeremy
# 4                 fraud_Keeling-Crist       misc_pos   41.96      Tyler
#
#       last gender                        street  ...      lat      long  \
# 0    Banks      F                561 Perry Cove  ...  36.0788  -81.1781
# ...

# %%
df.shape
# Out:
# (1852394, 23)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1852394 entries, 0 to 555718
# Data columns (total 23 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Unnamed: 0             int64
#  1   trans_date_trans_time  object
#  2   cc_num                 int64
#  3   merchant               object
#  4   category               object
#  5   amt                    float64
#  6   first                  object
#  7   last                   object
#  8   gender                 object
#  9   street                 object
#  10  city                   object
#  11  state                  object
#  12  zip                    int64
#  13  lat                    float64
#  14  long                   float64
#  15  city_pop               int64
#  16  job                    object
#  17  dob                    object
#  18  trans_num              object
#  19  unix_time              int64
#  20  merch_lat              float64
#  21  merch_long             float64
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0        cc_num           amt           zip           lat  \
# count  1.852394e+06  1.852394e+06  1.852394e+06  1.852394e+06  1.852394e+06
# mean   5.371934e+05  4.173860e+17  7.006357e+01  4.881326e+04  3.853931e+01
# std    3.669110e+05  1.309115e+18  1.592540e+02  2.688185e+04  5.071470e+00
# min    0.000000e+00  6.041621e+10  1.000000e+00  1.257000e+03  2.002710e+01
# 25%    2.315490e+05  1.800429e+14  9.640000e+00  2.623700e+04  3.466890e+01
# 50%    4.630980e+05  3.521417e+15  4.745000e+01  4.817400e+04  3.935430e+01
# 75%    8.335758e+05  4.642255e+15  8.310000e+01  7.204200e+04  4.194040e+01
# max    1.296674e+06  4.992346e+18  2.894890e+04  9.992100e+04  6.669330e+01
#
#                long      city_pop     unix_time     merch_lat    merch_long  \
# count  1.852394e+06  1.852394e+06  1.852394e+06  1.852394e+06  1.852394e+06
# mean  -9.022783e+01  8.864367e+04  1.358674e+09  3.853898e+01 -9.022794e+01
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'merchant', 'category',
#        'amt', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip',
#        'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time',
#        'merch_lat', 'merch_long', 'is_fraud'],
#       dtype='object')

# %%
df['is_fraud'].count()
# Out:
# 1852394

# %%
df['cc_num']
# Out:
# 0         2703186189652095
# 1             630423337322
# 2           38859492057661
# 3         3534093764340240
# 4          375534208663984
#                 ...
# 555714      30560609640617
# 555715    3556613125071656
# 555716    6011724471098086
# 555717       4079773899158
# 555718    4170689372027579
# Name: cc_num, Length: 1852394, dtype: int64

# %%
df.groupby('is_fraud').count()['cc_num'].plot.bar()
# Out:
# <Axes: xlabel='is_fraud'>

# %%
fraud=df[df['is_fraud']==1]
not_fraud=df[df['is_fraud']==0]

# %%
fraud.shape
# Out:
# (9651, 23)

# %%
not_fraud.shape
# Out:
# (1842743, 23)

# %%
fig,ax=plt.subplots(figsize=(15,15))
ax=sns.heatmap(df[[i for i in df.columns\
                         if df[i].dtype == 'int64' \
                            or df[i].dtype == 'float64']]\
                            .corr(),annot=True,cmap='coolwarm',vmin=-1,vmax=1)

# %%
fraud
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  \
# 2449          2449   2019-01-02 01:06:37     4613314721966
# 2472          2472   2019-01-02 01:47:29   340187018810220
# 2523          2523   2019-01-02 03:05:23   340187018810220
# 2546          2546   2019-01-02 03:38:03     4613314721966
# 2553          2553   2019-01-02 03:55:47   340187018810220
# ...            ...                   ...               ...
# 517197      517197   2020-12-22 22:05:48  2242176657877538
# 517274      517274   2020-12-22 22:18:07  2242176657877538
# 517341      517341   2020-12-22 22:31:48  2242176657877538
# 517529      517529   2020-12-22 23:06:03  2242176657877538
# 517571      517571   2020-12-22 23:13:39  2242176657877538
#
#                                    merchant       category      amt   first  \
# 2449                 fraud_Rutherford-Mertz    grocery_pos   281.06   Jason
# 2472       fraud_Jenkins, Hauck and Friesen  gas_transport    11.52   Misty
# ...

# %%
not_fraud
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  \
# 0                0   2019-01-01 00:00:18  2703186189652095
# 1                1   2019-01-01 00:00:44      630423337322
# 2                2   2019-01-01 00:00:51    38859492057661
# 3                3   2019-01-01 00:01:16  3534093764340240
# 4                4   2019-01-01 00:03:06   375534208663984
# ...            ...                   ...               ...
# 555714      555714   2020-12-31 23:59:07    30560609640617
# 555715      555715   2020-12-31 23:59:09  3556613125071656
# 555716      555716   2020-12-31 23:59:15  6011724471098086
# 555717      555717   2020-12-31 23:59:24     4079773899158
# 555718      555718   2020-12-31 23:59:34  4170689372027579
#
#                                   merchant        category     amt      first  \
# 0               fraud_Rippin, Kub and Mann        misc_net    4.97   Jennifer
# 1          fraud_Heller, Gutmann and Zieme     grocery_pos  107.23  Stephanie
# ...

# %%
df.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
# 2           2   2019-01-01 00:00:51    38859492057661
# 3           3   2019-01-01 00:01:16  3534093764340240
# 4           4   2019-01-01 00:03:06   375534208663984
#
#                              merchant       category     amt      first  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie
# 2                fraud_Lind-Buckridge  entertainment  220.11     Edward
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00     Jeremy
# 4                 fraud_Keeling-Crist       misc_pos   41.96      Tyler
#
#       last gender                        street  ...      lat      long  \
# 0    Banks      F                561 Perry Cove  ...  36.0788  -81.1781
# ...

# %%
df[df['is_fraud']==1].head()
# Out:
#       Unnamed: 0 trans_date_trans_time           cc_num  \
# 2449        2449   2019-01-02 01:06:37    4613314721966
# 2472        2472   2019-01-02 01:47:29  340187018810220
# 2523        2523   2019-01-02 03:05:23  340187018810220
# 2546        2546   2019-01-02 03:38:03    4613314721966
# 2553        2553   2019-01-02 03:55:47  340187018810220
#
#                               merchant       category     amt  first    last  \
# 2449            fraud_Rutherford-Mertz    grocery_pos  281.06  Jason  Murphy
# 2472  fraud_Jenkins, Hauck and Friesen  gas_transport   11.52  Misty    Hart
# 2523            fraud_Goodwin-Nitzsche    grocery_pos  276.31  Misty    Hart
# 2546            fraud_Erdman-Kertzmann  gas_transport    7.03  Jason  Murphy
# 2553                fraud_Koepp-Parker    grocery_pos  275.73  Misty    Hart
#
#      gender                     street  ...      lat     long  city_pop  \
# 2449      M  542 Steve Curve Suite 011  ...  35.9946 -81.7266       885
# ...

# %%
df.tail()
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  \
# 555714      555714   2020-12-31 23:59:07    30560609640617
# 555715      555715   2020-12-31 23:59:09  3556613125071656
# 555716      555716   2020-12-31 23:59:15  6011724471098086
# 555717      555717   2020-12-31 23:59:24     4079773899158
# 555718      555718   2020-12-31 23:59:34  4170689372027579
#
#                      merchant        category     amt    first     last  \
# 555714  fraud_Reilly and Sons  health_fitness   43.77  Michael    Olson
# 555715   fraud_Hoppe-Parisian       kids_pets  111.84     Jose  Vasquez
# 555716        fraud_Rau-Robel       kids_pets   86.88      Ann   Lawson
# 555717  fraud_Breitenberg LLC          travel    7.99     Eric  Preston
# 555718      fraud_Dare-Marvin   entertainment   38.13   Samuel     Frey
#
#        gender                      street  ...      lat      long  city_pop  \
# 555714      M         558 Michael Estates  ...  40.4931  -91.8912       519
# ...

# %%
df_balanced=pd.concat([not_fraud.sample(len(fraud),random_state=42),fraud])

# %%
df_balanced.head()
# Out:
#          Unnamed: 0 trans_date_trans_time            cc_num  \
# 517683       517683   2019-08-11 19:38:33  4681601008538160
# 1012042     1012042   2020-02-21 13:31:42  4653879239169997
# 581404       581404   2019-09-03 02:39:49  4334230547694630
# 1094893     1094893   2020-03-31 02:39:04  2256234701263057
# 433289       433289   2020-12-05 07:58:57  6011948324228984
#
#                                  merchant        category     amt  \
# 517683             fraud_Hermann and Sons    shopping_pos   50.81
# 1012042  fraud_Cronin, Kshlerin and Weber  health_fitness    1.97
# 581404             fraud_Rutherford-Mertz     grocery_pos  100.18
# 1094893                fraud_Kris-Padberg    shopping_pos    7.67
# 433289   fraud_Towne, Greenholt and Koepp    shopping_net  478.10
#
#                first    last gender                 street  ...      lat  \
# 517683         Tammy   Davis      F  77663 Colleen Freeway  ...  39.9148
# ...

# %%
df_balanced.shape
# Out:
# (19302, 23)

# %%
df_balanced.groupby('is_fraud').count()['cc_num'].plot.bar()
# Out:
# <Axes: xlabel='is_fraud'>

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'merchant', 'category',
#        'amt', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip',
#        'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time',
#        'merch_lat', 'merch_long', 'is_fraud'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1852394 entries, 0 to 555718
# Data columns (total 23 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Unnamed: 0             int64
#  1   trans_date_trans_time  object
#  2   cc_num                 int64
#  3   merchant               object
#  4   category               object
#  5   amt                    float64
#  6   first                  object
#  7   last                   object
#  8   gender                 object
#  9   street                 object
#  10  city                   object
#  11  state                  object
#  12  zip                    int64
#  13  lat                    float64
#  14  long                   float64
#  15  city_pop               int64
#  16  job                    object
#  17  dob                    object
#  18  trans_num              object
#  19  unix_time              int64
#  20  merch_lat              float64
#  21  merch_long             float64
# ...

# %%
df_balanced.drop(columns=['Unnamed: 0','merchant',
                   'cc_num',
                   'first',
                   'last',
                   'gender',
                   'trans_num',
                   'unix_time',
                   'street',
                   'merch_lat',
                   'merch_long',
                   'job',
                   'zip'],inplace=True)

# %%
df_balanced.head()
# Out:
#         trans_date_trans_time        category     amt          city state  \
# 517683    2019-08-11 19:38:33    shopping_pos   50.81   Moundsville    WV
# 1012042   2020-02-21 13:31:42  health_fitness    1.97  Smiths Grove    KY
# 581404    2019-09-03 02:39:49     grocery_pos  100.18       Freedom    WY
# 1094893   2020-03-31 02:39:04    shopping_pos    7.67      Grantham    NH
# 433289    2020-12-05 07:58:57    shopping_net  478.10         Paris    MS
#
#              lat      long  city_pop         dob  is_fraud
# 517683   39.9148  -80.7310     16183  1977-08-12         0
# 1012042  37.0581  -86.1938      6841  1999-06-06         0
# 581404   43.0172 -111.0292       471  1967-08-02         0
# 1094893  43.5103  -72.1334      2971  1948-04-11         0
# 433289   34.1992  -89.3820       297  1961-12-14         0

# %%
df_balanced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19302 entries, 517683 to 517571
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   trans_date_trans_time  19302 non-null  object
#  1   category               19302 non-null  object
#  2   amt                    19302 non-null  float64
#  3   city                   19302 non-null  object
#  4   state                  19302 non-null  object
#  5   lat                    19302 non-null  float64
#  6   long                   19302 non-null  float64
#  7   city_pop               19302 non-null  int64
#  8   dob                    19302 non-null  object
#  9   is_fraud               19302 non-null  int64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 2.1+ MB

# %%
df_balanced['trans_date_trans_time']=pd.to_datetime(df_balanced['trans_date_trans_time'])
df_balanced['dob']=pd.to_datetime(df_balanced['dob'])

# %%
df_balanced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19302 entries, 517683 to 517571
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   trans_date_trans_time  19302 non-null  datetime64[ns]
#  1   category               19302 non-null  object
#  2   amt                    19302 non-null  float64
#  3   city                   19302 non-null  object
#  4   state                  19302 non-null  object
#  5   lat                    19302 non-null  float64
#  6   long                   19302 non-null  float64
#  7   city_pop               19302 non-null  int64
#  8   dob                    19302 non-null  datetime64[ns]
#  9   is_fraud               19302 non-null  int64
# dtypes: datetime64[ns](2), float64(3), int64(2), object(3)
# memory usage: 2.1+ MB

# %%
df_balanced['trans_date_trans_time']=df_balanced['trans_date_trans_time'].dt.hour
df_balanced['dob']=df_balanced['dob'].dt.year

# %%
df_balanced=df_balanced.rename(columns={'trans_date_trans_time':'hour_transaction','dob':'age'})

# %%
def get_tod(hour):
  if 4 < hour['hour_transaction'] <= 12:
    ans='morning'
  elif 12 < hour['hour_transaction'] <= 20:
    ans='afternoon'
  elif hour['hour_transaction'] <= 4 or hour['hour_transaction'] > 20:
    ans='night'
  return ans

# %%
df_balanced['hour_transaction']=df_balanced.apply(get_tod,axis=1)

# %%
df_balanced.head()
# Out:
#         hour_transaction        category     amt          city state      lat  \
# 517683         afternoon    shopping_pos   50.81   Moundsville    WV  39.9148
# 1012042        afternoon  health_fitness    1.97  Smiths Grove    KY  37.0581
# 581404             night     grocery_pos  100.18       Freedom    WY  43.0172
# 1094893            night    shopping_pos    7.67      Grantham    NH  43.5103
# 433289           morning    shopping_net  478.10         Paris    MS  34.1992
#
#              long  city_pop   age  is_fraud
# 517683   -80.7310     16183  1977         0
# 1012042  -86.1938      6841  1999         0
# 581404  -111.0292       471  1967         0
# 1094893  -72.1334      2971  1948         0
# 433289   -89.3820       297  1961         0

# %%
from datetime import datetime

# %%
df_balanced['age']=datetime.now().year-df_balanced['age']

# %%
plt.figure(figsize=(15,15))
df_balanced[df_balanced['is_fraud']==1].groupby('age').count()['is_fraud'].plot.bar()
# Out:
# <Axes: xlabel='age'>

# %%
NUMERICAL_FEATURES = [i for i in df_balanced.columns if df_balanced[i].dtype == 'int64'\
                      or df_balanced[i].dtype =='int32' \
                      or df_balanced[i].dtype =='float64']
CATEGORICAL_FEATURES = [i for i in df_balanced.columns if df_balanced[i].dtype == 'object']

# %%
NUMERICAL_FEATURES
# Out:
# ['amt', 'lat', 'long', 'city_pop', 'age', 'is_fraud']

# %%
CATEGORICAL_FEATURES
# Out:
# ['hour_transaction', 'category', 'city', 'state']

# %%
df_balanced[['is_fraud', 'age']] = df_balanced[['is_fraud', 'age']].astype('float64')

# %%
sns.boxplot(df_balanced[NUMERICAL_FEATURES])
# Out:
# <Axes: >

# %%
sns.boxplot(df_balanced['amt'])
# Out:
# <Axes: ylabel='amt'>

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split

# %%
ht=pd.get_dummies(df_balanced[CATEGORICAL_FEATURES],drop_first=True)

# %%
df_balanced=pd.concat([df_balanced,ht],axis=1)

# %%
df_balanced.drop(columns=CATEGORICAL_FEATURES,inplace=True)

# %%
X=df_balanced.drop(columns=['is_fraud'])
y=df_balanced['is_fraud']

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
predication=lr.predict(x_test)

# %%
confusion_matrix(y_test,predication)
# Out:
# array([[3056,  139],
#        [ 741, 2434]])

# %%
classification_report(y_test,predication)
# Out:
# '              precision    recall  f1-score   support\n\n         0.0       0.80      0.96      0.87      3195\n         1.0       0.95      0.77      0.85      3175\n\n    accuracy                           0.86      6370\n   macro avg       0.88      0.86      0.86      6370\nweighted avg       0.88      0.86      0.86      6370\n'
